# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'c:\users\kowshik\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'c:\users\kowshik\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib.image import imread
import matplotlib.pyplot as plt
import seaborn as sns
parasite_images_dir = 'C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized'

uninfected_images_dir = 'C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected'

parasite_images_dir = os.listdir(parasite_images_dir)
len(parasite_images_dir)
# Out:
# 13780

# %%
uninfected_images_dir = os.listdir(uninfected_images_dir)
len(uninfected_images_dir)
# Out:
# 13780

# %%
file = random.sample(os.listdir('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized'),25)
plt.figure(figsize=(15,15))
for i in range(1,len(file)):
    row = i
    image = imread('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized/'+file[i])
    plt.subplot(5,5,row)
    plt.imshow(image)
plt.show()

# %%
file_ = random.sample(os.listdir('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected'),26)
plt.figure(figsize=(15,15))
for i in range(1,len(file_)):
    row = i
    image = imread('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected'+'/'+file_[i])
    plt.subplot(5,5,row)
    plt.imshow(image)
plt.show()

# %%
# lets write the directory of a single Parasitized cell and take a look at it using imread
para_cell= 'C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_163.png'
para_cell
# Out:
# 'C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_163.png'

# %%
plt.imshow(imread(para_cell))

# %%
# lets write the directory of a single Uninfected cell and take a look at it using imread
uninfected_cell = 'C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected/C100P61ThinF_IMG_20150918_144104_cell_25.png'
uninfected_cell
# Out:
# 'C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected/C100P61ThinF_IMG_20150918_144104_cell_25.png'

# %%
plt.imshow(imread(uninfected_cell))

# %%
dim1 = []
dim2 = []
for image_filename in os.listdir('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized'):
    if 'Thumbs.db' not in image_filename:
        img = imread('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Parasitized/'+image_filename)
        d1,d2,colors = img.shape
        dim1.append(d1)
        dim2.append(d2)
        
sns.jointplot(dim1,dim2)
# Out:
# c:\users\kowshik\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dim1_ = []
dim2_ = []
for image_filename in os.listdir('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected'):
    if 'Thumbs.db' not in image_filename:
        img = imread('C:/Users/kowshik/Downloads/archive (1)/cell_images/cell_images/Uninfected/'+image_filename)
        d1,d2,colors = img.shape
        dim1_.append(d1)
        dim2_.append(d2)
        
sns.jointplot(dim1_,dim2_)
# Out:
# c:\users\kowshik\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.2 is available.
# You should consider upgrading via the 'c:\users\kowshik\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import os
import cv2
# %matplotlib inline
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.layers import Dense,Flatten,Dropout,BatchNormalization
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
